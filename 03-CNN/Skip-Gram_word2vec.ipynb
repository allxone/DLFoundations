# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [03:31, 148KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7948 0.0477 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7521 0.0414 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6680 0.0409 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6842 0.0411 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6190 0.0409 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6595 0.0413 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6097 0.0418 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6494 0.0418 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5519 0.0415 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4903 0.0414 sec/batch
# Nearest to three: max, reason, mollified, mouhoun, customization, logarithmic, gunnery, lambdamoo,
# Nearest to only: polymyositis, young, customers, relatedness, hamitic, civilisation, trades, donnie,
# Nearest to four: bolden, ghent, applicable, intruded, blog, annuities, apps, frida,
# Nearest to such: superpowered, bibliographical, manners, beavis, metalworking, tagore, cori, hussar,
# Nearest to about: hoplite, anakin, resurrection, saracens, lionhead, lobose, haskalah, esplanade,
# Nearest to or: stadtholder, journeys, fringing, nicky, oleg, fahd, hulagu, deeps,
# Nearest to many: puzo, sociopolitical, ursine, zygmunt, spared, cards, herod, chalcis,
# Nearest to history: presumptive, makah, pheromones, multivariate, exp, rationale, discussions, boudicca,
# Nearest to troops: ski, visitors, sculptural, only, fanzines, disused, pituitary, regulators,
# Nearest to nobel: hare, vang, goddard, phys, matheson, emsworth, fln, albertine,
# Nearest to notes: sends, teil, emigrants, masala, amn, distinction, flops, deleted,
# Nearest to prince: etat, fractions, tawi, cruisers, nostradamus, whitechapel, firaxis, magnetic,
# Nearest to active: disingenuous, waterproof, rpm, rug, pies, vinton, milan, extensively,
# Nearest to mathematics: urundi, accessible, miletus, grievous, biscuits, murat, conserve, signify,
# Nearest to magazine: abingdon, luxury, cheetah, democratically, licenses, banknote, vibrations, missionaries,
# Nearest to freedom: hindemith, inlets, escalation, within, decrypting, frequentist, exptime, tee,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5783 0.0428 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4417 0.0409 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4005 0.0412 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2955 0.0406 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2831 0.0414 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2280 0.0419 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1629 0.0413 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1562 0.0411 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0722 0.0405 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0336 0.0417 sec/batch
# Nearest to three: max, reason, customization, inside, distance, regarded, st, mother,
# Nearest to only: young, customers, troops, integrating, trades, negative, civilisation, relatedness,
# Nearest to four: applicable, ghent, bolden, blog, operated, origin, intruded, scoring,
# Nearest to such: superpowered, bibliographical, manners, beavis, tagore, metalworking, familes, remorse,
# Nearest to about: resurrection, number, hoplite, occasion, quotes, anakin, century, chiropractic,
# Nearest to or: journeys, stadtholder, fringing, anything, reserved, nicky, transportation, oleg,
# Nearest to many: cards, herod, puzo, sociopolitical, fund, spared, zygmunt, help,
# Nearest to history: discussions, presumptive, rationale, panama, exp, multivariate, pheromones, resolving,
# Nearest to troops: visitors, only, ski, sum, disappear, sculptural, faith, ritorno,
# Nearest to nobel: hare, phys, vang, goddard, matheson, fln, sel, emsworth,
# Nearest to notes: teil, sends, distinction, airborne, flops, deleted, emigrants, masala,
# Nearest to prince: etat, fractions, cruisers, ms, donohue, monastic, nostradamus, hanged,
# Nearest to active: rpm, disingenuous, waterproof, underlying, certainly, extensively, pies, margins,
# Nearest to mathematics: accessible, miletus, biscuits, religions, keep, urundi, signify, proclaimed,
# Nearest to magazine: luxury, abingdon, democratically, vibrations, banknote, missionaries, liquidity, licenses,
# Nearest to freedom: hindemith, escalation, within, exptime, inlets, precedence, tee, syntax,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9905 0.0448 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9691 0.0462 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9343 0.0425 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9216 0.0424 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8642 0.0410 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8707 0.0418 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8673 0.0424 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8380 0.0432 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8340 0.0426 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8574 0.0425 sec/batch
# Nearest to three: max, logarithmic, customization, st, fluids, reason, mouhoun, inside,
# Nearest to only: troops, customers, civilisation, integrating, young, trades, relatedness, negative,
# Nearest to four: ghent, applicable, operated, bolden, blog, intruded, arabs, marsh,
# Nearest to such: bibliographical, manners, superpowered, metalworking, remorse, provoke, familes, unethical,
# Nearest to about: resurrection, hoplite, quotes, lobose, anakin, crimes, occasion, number,
# Nearest to or: journeys, stadtholder, fringing, nicky, oleg, anything, ghana, reserved,
# Nearest to many: sociopolitical, spared, puzo, herod, fund, cards, chalcis, zygmunt,
# Nearest to history: presumptive, panama, rationale, discussions, exp, pheromones, robe, resolving,
# Nearest to troops: visitors, ski, only, ritorno, sculptural, amphibious, disappear, she,
# Nearest to nobel: hare, phys, vang, homomorphism, goddard, lucrezia, dominator, emsworth,
# Nearest to notes: sends, teil, deleted, flops, masala, airborne, distinction, emigrants,
# Nearest to prince: etat, donohue, ms, monastic, hanged, fractions, wealthiest, horror,
# Nearest to active: waterproof, disingenuous, rpm, motifs, margins, underlying, sending, rockefeller,
# Nearest to mathematics: accessible, amendment, worldly, biscuits, signify, miletus, religions, grievous,
# Nearest to magazine: abingdon, luxury, cheetah, democratically, banknote, liquidity, missionaries, licenses,
# Nearest to freedom: hindemith, escalation, inlets, insurance, within, exptime, tee, greetings,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8485 0.0447 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8275 0.0423 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7641 0.0415 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7562 0.0417 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7789 0.0423 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7436 0.0421 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7310 0.0403 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7777 0.0412 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7503 0.0417 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6818 0.0412 sec/batch
# Nearest to three: max, st, customization, logarithmic, zero, gunnery, aylmer, manager,
# Nearest to only: trades, troops, civilisation, integrating, customers, relatedness, young, negative,
# Nearest to four: ghent, operated, annuities, bolden, applicable, poet, butch, blog,
# Nearest to such: bibliographical, manners, metalworking, unethical, remorse, superpowered, provoke, familes,
# Nearest to about: resurrection, quotes, hoplite, saracens, seattleites, lobose, gamers, anakin,
# Nearest to or: stadtholder, journeys, fringing, nicky, oleg, reserved, ghana, glover,
# Nearest to many: sociopolitical, zygmunt, spared, puzo, herod, fund, ramone, televangelist,
# Nearest to history: presumptive, panama, pheromones, rationale, lifestyles, sharif, discussions, exp,
# Nearest to troops: visitors, ski, only, amphibious, sculptural, disused, ritorno, estates,
# Nearest to nobel: hare, phys, goddard, lucrezia, matheson, sel, kenny, vang,
# Nearest to notes: sends, teil, flops, emigrants, masala, deleted, distinction, airborne,
# Nearest to prince: etat, donohue, ms, monastic, hanged, wealthiest, cruisers, adopts,
# Nearest to active: disingenuous, waterproof, rug, pies, rpm, vinton, margins, motifs,
# Nearest to mathematics: accessible, amendment, worldly, urundi, biscuits, murat, signify, miletus,
# Nearest to magazine: abingdon, cheetah, luxury, banknote, democratically, liquidity, struck, shells,
# Nearest to freedom: hindemith, inlets, escalation, insurance, exptime, tee, greetings, couture,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7189 0.0432 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6849 0.0411 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6779 0.0420 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6499 0.0414 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6521 0.0412 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6460 0.0423 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6099 0.0294 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5503 0.0415 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4914 0.0420 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4949 0.0412 sec/batch
# Nearest to three: max, zero, inventor, customization, aylmer, st, logarithmic, porta,
# Nearest to only: trades, minarets, civilisation, integrating, troops, completions, customers, treating,
# Nearest to four: ghent, butch, poet, annuities, bolden, frida, regains, guitarist,
# Nearest to such: bibliographical, superpowered, unethical, manners, remorse, metalworking, provoke, polygyny,
# Nearest to about: resurrection, saracens, quotes, seattleites, hibernate, hoplite, lionhead, lobose,
# Nearest to or: stadtholder, journeys, unprotected, fringing, atom, reserved, nicky, fahd,
# Nearest to many: sociopolitical, herod, zygmunt, spared, puzo, fund, ramone, chalcis,
# Nearest to history: presumptive, pheromones, sharif, lifestyles, panama, vogel, multivariate, rationale,
# Nearest to troops: visitors, ski, amphibious, only, disused, sculptural, militiamen, nigeria,
# Nearest to nobel: hare, kenny, goddard, lucrezia, phys, sel, prize, jan,
# Nearest to notes: sends, teil, masala, flops, emigrants, deleted, bradman, ubiquity,
# Nearest to prince: etat, monastic, hanged, donohue, valdez, ms, wealthiest, fianc,
# Nearest to active: disingenuous, waterproof, pies, vinton, rug, margins, vojvodina, motifs,
# Nearest to mathematics: accessible, urundi, worldly, amendment, tan, biscuits, murat, grievous,
# Nearest to magazine: abingdon, cheetah, banknote, luxury, teddy, liquidity, purist, columbine,
# Nearest to freedom: hindemith, inlets, escalation, greetings, exptime, tee, laodicea, insurance,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4758 0.0419 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4904 0.0408 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4223 0.0421 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5241 0.0410 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5020 0.0409 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4603 0.0410 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4622 0.0428 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3929 0.0417 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4342 0.0411 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3965 0.0412 sec/batch
# Nearest to three: zero, customization, aylmer, max, km, logarithmic, inventor, two,
# Nearest to only: trades, minarets, integrating, civilisation, negative, completions, treating, customers,
# Nearest to four: ghent, annuities, butch, two, regains, bolden, nathanael, operated,
# Nearest to such: bibliographical, metalworking, unethical, superpowered, pluralistic, hellraiser, mutt, duplication,
# Nearest to about: quotes, saracens, resurrection, seattleites, hibernate, lobose, anakin, hoplite,
# Nearest to or: stadtholder, unprotected, reserved, atom, attached, journeys, fringing, fahd,
# Nearest to many: sociopolitical, zygmunt, spared, ramone, puzo, fund, amorphous, herod,
# Nearest to history: presumptive, pheromones, sharif, amg, multivariate, vogel, lifestyles, panama,
# Nearest to troops: visitors, ski, amphibious, disused, sculptural, militiamen, only, ibrahim,
# Nearest to nobel: phys, goddard, kenny, hare, lucrezia, sel, moira, prize,
# Nearest to notes: flops, masala, sends, teil, deleted, ubiquity, saka, distinction,
# Nearest to prince: etat, monastic, hanged, donohue, valdez, fianc, ms, penn,
# Nearest to active: disingenuous, rug, pies, waterproof, margins, oscars, sanctioning, structuralist,
# Nearest to mathematics: urundi, accessible, tan, funniest, worldly, biscuits, plasticizers, anodic,
# Nearest to magazine: abingdon, cheetah, luxury, teddy, banknote, columbine, purist, liquidity,
# Nearest to freedom: hindemith, laodicea, inlets, escalation, greetings, insurance, exptime, casas,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4089 0.0430 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3807 0.0407 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4051 0.0408 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4055 0.0410 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3858 0.0409 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4303 0.0406 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3696 0.0406 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3780 0.0405 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4014 0.0411 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3852 0.0410 sec/batch
# Nearest to three: zero, aylmer, two, logarithmic, st, customization, max, inventor,
# Nearest to only: minarets, civilisation, integrating, trades, customers, completions, negative, revolutionizing,
# Nearest to four: two, ghent, regains, nathanael, bolden, annuities, cfa, butch,
# Nearest to such: bibliographical, metalworking, pluralistic, hellraiser, unethical, superpowered, nevermind, duplication,
# Nearest to about: quotes, resurrection, saracens, seattleites, lobose, hoplite, hibernate, anakin,
# Nearest to or: stadtholder, unprotected, attached, reserved, fringing, fahd, journeys, anything,
# Nearest to many: sociopolitical, ramone, zygmunt, fund, spared, puzo, herod, detecting,
# Nearest to history: presumptive, pheromones, amg, multivariate, sharif, vogel, lifestyles, panama,
# Nearest to troops: visitors, ski, amphibious, militiamen, disused, ibrahim, sculptural, only,
# Nearest to nobel: phys, kenny, goddard, hare, lucrezia, sel, dominator, prize,
# Nearest to notes: flops, masala, deleted, sends, ubiquity, saka, distinction, teil,
# Nearest to prince: monastic, etat, hanged, donohue, valdez, francis, penn, fianc,
# Nearest to active: disingenuous, rug, pies, waterproof, margins, rockefeller, vojvodina, nonsignatory,
# Nearest to mathematics: urundi, tan, accessible, emendations, plasticizers, studied, harakat, anodic,
# Nearest to magazine: abingdon, cheetah, teddy, luxury, banknote, columbine, purist, comedies,
# Nearest to freedom: laodicea, insurance, hindemith, couture, exptime, greetings, escalation, fragility,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3430 0.0432 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3732 0.0434 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3319 0.0416 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3262 0.0413 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3863 0.0411 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3434 0.0411 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3538 0.0412 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3963 0.0410 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3321 0.0411 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3292 0.0409 sec/batch
# Nearest to three: zero, two, aylmer, km, eight, four, nubians, customization,
# Nearest to only: civilisation, minarets, trades, completions, negative, customers, integrating, revolutionizing,
# Nearest to four: two, ghent, regains, nathanael, annuities, three, eight, bolden,
# Nearest to such: bibliographical, metalworking, unethical, hellraiser, pluralistic, duplication, superpowered, neurologists,
# Nearest to about: quotes, saracens, resurrection, hibernate, hoplite, anakin, lobose, seattleites,
# Nearest to or: stadtholder, reserved, attached, unprotected, fringing, merely, fahd, ashamed,
# Nearest to many: zygmunt, sociopolitical, ramone, fund, puzo, herod, spared, televangelist,
# Nearest to history: presumptive, amg, sharif, pheromones, lifestyles, panama, vogel, bourbon,
# Nearest to troops: amphibious, ski, visitors, estates, ibrahim, militiamen, reprisal, disused,
# Nearest to nobel: phys, goddard, kenny, lucrezia, hare, simone, dominator, sel,
# Nearest to notes: flops, masala, deleted, saka, teil, distinction, ubiquity, bradman,
# Nearest to prince: monastic, etat, donohue, valdez, francis, hanged, librarian, amedeo,
# Nearest to active: disingenuous, rug, waterproof, rockefeller, nonsignatory, pies, sherpa, sanctioning,
# Nearest to mathematics: studied, urundi, emendations, tan, plasticizers, harakat, miletus, rejects,
# Nearest to magazine: abingdon, cheetah, banknote, teddy, news, comedies, luxury, surfing,
# Nearest to freedom: laodicea, insurance, exptime, fragility, couture, escalation, greetings, casas,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3483 0.0420 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3129 0.0407 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3781 0.0402 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3734 0.0401 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3797 0.0401 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2718 0.0404 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3132 0.0400 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3039 0.0404 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2263 0.0404 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2904 0.0408 sec/batch
# Nearest to three: zero, two, aylmer, four, eight, max, customization, inventor,
# Nearest to only: minarets, trades, civilisation, integrating, customers, revolutionizing, negative, uighur,
# Nearest to four: two, eight, ghent, three, one, seven, regains, five,
# Nearest to such: bibliographical, metalworking, pluralistic, duplication, hellraiser, nevermind, unethical, cations,
# Nearest to about: quotes, saracens, hoplite, resurrection, hibernate, occasion, lionhead, gauguin,
# Nearest to or: stadtholder, reserved, attached, anything, merely, fahd, sapiens, phan,
# Nearest to many: sociopolitical, ramone, zygmunt, martial, fund, televangelist, spared, detecting,
# Nearest to history: amg, presumptive, sharif, lifestyles, pheromones, multivariate, vogel, hmcs,
# Nearest to troops: amphibious, visitors, ski, militiamen, reprisal, ibrahim, estates, putsch,
# Nearest to nobel: goddard, phys, prize, kenny, simone, lucrezia, hare, sel,
# Nearest to notes: flops, masala, deleted, teil, saka, distinction, explained, congruences,
# Nearest to prince: monastic, etat, valdez, librarian, donohue, septimania, amedeo, hanged,
# Nearest to active: disingenuous, rug, nonsignatory, vojvodina, waterproof, sherpa, oscars, sanctioning,
# Nearest to mathematics: studied, emendations, urundi, tan, plasticizers, accessible, miletus, contradiction,
# Nearest to magazine: abingdon, cheetah, comedies, columbine, news, teddy, purist, banknote,
# Nearest to freedom: insurance, exptime, laodicea, greetings, fragility, escalation, casas, luther,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2888 0.0425 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2970 0.0411 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3096 0.0183 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2312 0.0414 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1966 0.0411 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1891 0.0409 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1840 0.0409 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1661 0.0412 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1558 0.0411 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1571 0.0406 sec/batch
# Nearest to three: zero, two, four, aylmer, km, eight, max, est,
# Nearest to only: minarets, civilisation, trades, customers, completions, revolutionizing, integrating, tackles,
# Nearest to four: two, three, eight, one, five, seven, regains, zero,
# Nearest to such: bibliographical, superpowered, pluralistic, metalworking, hellraiser, nevermind, duplication, mutt,
# Nearest to about: saracens, quotes, hibernate, resurrection, gauguin, anakin, limestone, hoplite,
# Nearest to or: stadtholder, reserved, attached, unprotected, receptive, anything, phan, sapiens,
# Nearest to many: sociopolitical, ramone, zygmunt, martial, fund, bitkeeper, theropod, moratorium,
# Nearest to history: amg, sharif, presumptive, multivariate, lifestyles, goers, pheromones, bourbon,
# Nearest to troops: amphibious, ski, visitors, reprisal, militiamen, ritorno, ibrahim, only,
# Nearest to nobel: goddard, phys, prize, kenny, sel, simone, lucrezia, branwell,
# Nearest to notes: flops, masala, teil, saka, deleted, distinction, congruences, bradman,
# Nearest to prince: monastic, etat, donohue, valdez, librarian, septimania, hanged, amedeo,
# Nearest to active: disingenuous, rug, nonsignatory, sherpa, rpm, pies, daubert, waterproof,
# Nearest to mathematics: studied, tan, miletus, emendations, urundi, plasticizers, mit, mathematical,
# Nearest to magazine: abingdon, cheetah, columbine, comedies, news, surfing, purist, teddy,
# Nearest to freedom: insurance, laodicea, exptime, escalation, greetings, casas, fragility, couture,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.1751 0.0418 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2039 0.0410 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1952 0.0416 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1265 0.0407 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1383 0.0403 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1229 0.0406 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1179 0.0401 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1363 0.0401 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1754 0.0401 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1319 0.0402 sec/batch
# Nearest to three: zero, two, four, aylmer, eight, est, five, km,
# Nearest to only: minarets, revolutionizing, civilisation, telomere, completions, tackles, customers, all,
# Nearest to four: two, three, zero, seven, one, eight, five, regains,
# Nearest to such: metalworking, duplication, bibliographical, pluralistic, hellraiser, superpowered, mutt, neurologists,
# Nearest to about: quotes, saracens, hibernate, resurrection, limestone, guesswork, gauguin, lobose,
# Nearest to or: unprotected, reserved, attached, stadtholder, anything, attainable, cheating, they,
# Nearest to many: ramone, sociopolitical, martial, bitkeeper, theropod, cards, fund, zygmunt,
# Nearest to history: amg, sharif, vogel, multivariate, presumptive, chronology, lifestyles, pheromones,
# Nearest to troops: amphibious, ski, visitors, putsch, militiamen, reprisal, ibrahim, ritorno,
# Nearest to nobel: phys, goddard, prize, sel, kenny, thysanoessa, lucrezia, hare,
# Nearest to notes: flops, masala, saka, teil, bradman, deleted, toland, ubiquity,
# Nearest to prince: monastic, etat, septimania, donohue, amedeo, librarian, kal, valdez,
# Nearest to active: disingenuous, rug, nonsignatory, daubert, sherpa, waterproof, sanctioning, margins,
# Nearest to mathematics: studied, tan, miletus, mit, urundi, emendations, accessible, funniest,
# Nearest to magazine: abingdon, news, comedies, cheetah, columbine, purist, surfing, archiving,
# Nearest to freedom: insurance, laodicea, exptime, greetings, escalation, frequentist, couture, modernisation,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1787 0.0419 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1915 0.0401 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1553 0.0403 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1341 0.0402 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1499 0.0400 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1888 0.0404 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1686 0.0405 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0993 0.0402 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0944 0.0402 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1500 0.0398 sec/batch
# Nearest to three: zero, two, four, eight, five, six, aylmer, nine,
# Nearest to only: minarets, revolutionizing, telomere, civilisation, completions, twelve, fj, tackles,
# Nearest to four: two, three, one, seven, zero, eight, five, regains,
# Nearest to such: metalworking, bibliographical, duplication, hellraiser, superpowered, neurologists, experimental, zionist,
# Nearest to about: quotes, hibernate, resurrection, saracens, hoplite, edu, guesswork, occasion,
# Nearest to or: unprotected, reserved, anything, attainable, receptive, attached, stadtholder, nicky,
# Nearest to many: sociopolitical, bitkeeper, ramone, theropod, martial, zygmunt, fund, amorphous,
# Nearest to history: amg, sharif, chronology, presumptive, multivariate, vogel, lefkow, hmcs,
# Nearest to troops: amphibious, reprisal, militiamen, ski, putsch, ibrahim, visitors, ritorno,
# Nearest to nobel: phys, goddard, prize, hawley, thysanoessa, dominator, lucrezia, maslow,
# Nearest to notes: flops, saka, masala, era, bradman, deleted, explained, congruences,
# Nearest to prince: monastic, etat, septimania, librarian, kal, donohue, amedeo, sixteenth,
# Nearest to active: disingenuous, rug, nonsignatory, daubert, rockefeller, sanctioning, rpm, sherpa,
# Nearest to mathematics: studied, emendations, miletus, tan, mit, urundi, mathematical, contradiction,
# Nearest to magazine: abingdon, news, columbine, cheetah, teddy, surfing, archiving, purist,
# Nearest to freedom: laodicea, exptime, greetings, insurance, modernisation, escalation, frequentist, couture,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1952 0.0413 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1450 0.0401 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1387 0.0407 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1638 0.0404 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1330 0.0403 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1165 0.0402 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1748 0.0403 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1309 0.0406 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1561 0.0404 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1899 0.0403 sec/batch
# Nearest to three: two, zero, four, eight, five, six, nine, aylmer,
# Nearest to only: minarets, revolutionizing, civilisation, completions, all, telomere, tackles, negative,
# Nearest to four: two, three, one, seven, five, eight, zero, regains,
# Nearest to such: bibliographical, experimental, metalworking, superpowered, hellraiser, nevermind, zionist, duplication,
# Nearest to about: quotes, saracens, hibernate, edu, rebounds, resurrection, occasion, lionhead,
# Nearest to or: reserved, unprotected, anything, nicky, stadtholder, attainable, attached, ultrasonic,
# Nearest to many: sociopolitical, bitkeeper, ramone, martial, zygmunt, theropod, weizmann, spared,
# Nearest to history: chronology, sharif, amg, lefkow, lifestyles, presumptive, goers, panama,
# Nearest to troops: amphibious, reprisal, putsch, militiamen, ski, ibrahim, ritorno, shahade,
# Nearest to nobel: phys, prize, goddard, kenny, hawley, maslow, lucrezia, laureate,
# Nearest to notes: saka, flops, masala, era, ber, bradman, congruences, harp,
# Nearest to prince: monastic, etat, kal, septimania, donohue, librarian, amedeo, airforce,
# Nearest to active: disingenuous, nonsignatory, rug, mpr, daubert, sanctioning, vojvodina, sherpa,
# Nearest to mathematics: studied, miletus, emendations, tan, urundi, layton, entropy, funniest,
# Nearest to magazine: abingdon, news, comedies, purist, columbine, cheetah, surfing, archiving,
# Nearest to freedom: greetings, laodicea, exptime, insurance, escalation, mcqueen, modernisation, casas,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2226 0.0418 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1240 0.0407 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1174 0.0404 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0830 0.0403 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0289 0.0407 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1197 0.0407 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1308 0.0406 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1169 0.0410 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1525 0.0068 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0764 0.0408 sec/batch
# Nearest to three: two, zero, four, five, eight, six, nine, one,
# Nearest to only: minarets, telomere, revolutionizing, tackles, all, completions, civilisation, fj,
# Nearest to four: two, three, one, five, seven, zero, eight, est,
# Nearest to such: hellraiser, zionist, metalworking, pluralistic, bibliographical, experimental, superpowered, duplication,
# Nearest to about: quotes, saracens, guesswork, gauguin, resurrection, prevalence, limestone, hibernate,
# Nearest to or: reserved, ultrasonic, unprotected, attached, anything, cheating, attainable, centipede,
# Nearest to many: bitkeeper, martial, sociopolitical, ramone, theropod, cards, weizmann, zygmunt,
# Nearest to history: sharif, chronology, multivariate, amg, goers, external, lifestyles, lefkow,
# Nearest to troops: amphibious, reprisal, militiamen, putsch, ski, ibrahim, ritorno, disused,
# Nearest to nobel: phys, prize, goddard, hawley, maslow, thysanoessa, lucrezia, kenny,
# Nearest to notes: flops, saka, masala, era, harp, congruences, ber, expound,
# Nearest to prince: monastic, kal, etat, donohue, septimania, librarian, amedeo, fianc,
# Nearest to active: disingenuous, nonsignatory, mpr, vojvodina, sanctioning, sherpa, daubert, astroturf,
# Nearest to mathematics: studied, miletus, urundi, emendations, tan, mit, layton, entropy,
# Nearest to magazine: abingdon, news, comedies, columbine, purist, surfing, cheetah, archiving,
# Nearest to freedom: greetings, laodicea, insurance, exptime, escalation, modernisation, frequentist, mcqueen,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0476 0.0420 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0582 0.0405 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0392 0.0408 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0175 0.0407 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0205 0.0408 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9995 0.0409 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0539 0.0409 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0510 0.0410 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0749 0.0410 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0320 0.0406 sec/batch
# Nearest to three: zero, two, four, five, six, eight, nine, one,
# Nearest to only: minarets, telomere, all, completions, revolutionizing, tackles, meteoroids, fj,
# Nearest to four: two, three, one, seven, five, zero, eight, regains,
# Nearest to such: hellraiser, metalworking, zionist, experimental, neurologists, superpowered, duplication, pluralistic,
# Nearest to about: saracens, quotes, resurrection, hibernate, prevalence, guesswork, limestone, gauguin,
# Nearest to or: reserved, attached, unprotected, ultrasonic, cheating, attainable, anything, receptive,
# Nearest to many: martial, bitkeeper, sociopolitical, theropod, ramone, cards, weizmann, maintaining,
# Nearest to history: sharif, chronology, multivariate, amg, lefkow, vogel, brief, lifestyles,
# Nearest to troops: amphibious, reprisal, militiamen, ski, ritorno, disused, shahade, ecclestone,
# Nearest to nobel: phys, prize, goddard, maslow, hawley, laureate, kenny, thysanoessa,
# Nearest to notes: flops, masala, saka, era, harp, congruences, ber, toland,
# Nearest to prince: monastic, kal, donohue, etat, septimania, fianc, librarian, ms,
# Nearest to active: nonsignatory, disingenuous, mpr, sanctioning, sherpa, capablanca, vojvodina, daubert,
# Nearest to mathematics: studied, miletus, urundi, layton, mit, emendations, funniest, tan,
# Nearest to magazine: abingdon, news, comedies, columbine, purist, surfing, cheetah, archiving,
# Nearest to freedom: laodicea, greetings, insurance, exptime, escalation, mcqueen, modernisation, sturt,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9790 0.0424 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9785 0.0421 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9753 0.0406 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0249 0.0409 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0339 0.0401 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0476 0.0424 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0371 0.0428 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0804 0.0425 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0423 0.0414 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0212 0.0514 sec/batch
# Nearest to three: zero, two, four, five, six, eight, one, nine,
# Nearest to only: all, telomere, minarets, revolutionizing, completions, tackles, fj, meteoroids,
# Nearest to four: two, three, one, five, seven, zero, eight, regains,
# Nearest to such: pluralistic, zionist, superpowered, metalworking, bibliographical, experimental, hellraiser, duplication,
# Nearest to about: quotes, resurrection, occasion, guesswork, hibernate, prevalence, saberhagen, saracens,
# Nearest to or: ultrasonic, reserved, attainable, unprotected, expressions, anything, cheating, attached,
# Nearest to many: bitkeeper, martial, sociopolitical, theropod, cards, ramone, weizmann, maintaining,
# Nearest to history: chronology, amg, sharif, multivariate, brief, lefkow, vogel, goers,
# Nearest to troops: amphibious, reprisal, militiamen, shahade, ski, ibrahim, ritorno, putsch,
# Nearest to nobel: phys, prize, goddard, maslow, laureate, hawley, lucrezia, thysanoessa,
# Nearest to notes: saka, era, masala, harp, flops, periods, expound, congruences,
# Nearest to prince: monastic, kal, septimania, donohue, etat, librarian, amedeo, fianc,
# Nearest to active: mpr, nonsignatory, disingenuous, sanctioning, capablanca, daubert, sherpa, rug,
# Nearest to mathematics: studied, miletus, mit, urundi, emendations, layton, funniest, tan,
# Nearest to magazine: abingdon, news, columbine, purist, comedies, archiving, alphabetically, scuba,
# Nearest to freedom: laodicea, exptime, greetings, insurance, escalation, mcqueen, modernisation, sturt,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9895 0.0421 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0303 0.0405 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0464 0.0409 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0386 0.0404 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0658 0.0406 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0204 0.0407 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0154 0.0407 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0434 0.0411 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0604 0.0409 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0390 0.0420 sec/batch
# Nearest to three: two, zero, four, five, six, eight, nine, one,
# Nearest to only: all, revolutionizing, minarets, completions, fj, civilisation, telomere, meteoroids,
# Nearest to four: two, three, one, seven, zero, five, eight, nine,
# Nearest to such: superpowered, zionist, experimental, bibliographical, pluralistic, hellraiser, duplication, metalworking,
# Nearest to about: quotes, guesswork, resurrection, hibernate, occasion, saberhagen, saracens, dreyer,
# Nearest to or: reserved, unprotected, attainable, ultrasonic, anything, cheating, attached, receptive,
# Nearest to many: bitkeeper, martial, sociopolitical, weizmann, theropod, ramone, elbl, stranding,
# Nearest to history: sharif, chronology, amg, panama, lefkow, goers, brief, myths,
# Nearest to troops: amphibious, reprisal, militiamen, shahade, putsch, ibrahim, ecclestone, wounded,
# Nearest to nobel: phys, prize, maslow, goddard, hawley, laureate, thysanoessa, lucrezia,
# Nearest to notes: saka, era, harp, masala, congruences, flops, periods, explained,
# Nearest to prince: monastic, kal, septimania, brother, etat, librarian, donohue, airforce,
# Nearest to active: sanctioning, nonsignatory, mpr, capablanca, disingenuous, daubert, rug, athos,
# Nearest to mathematics: studied, miletus, urundi, mit, layton, emendations, funniest, tan,
# Nearest to magazine: abingdon, news, purist, columbine, alphabetically, archiving, comedies, koch,
# Nearest to freedom: exptime, laodicea, greetings, insurance, escalation, mcqueen, modernisation, decrypting,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0111 0.0417 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9917 0.0407 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0306 0.0424 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0348 0.0415 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0405 0.0404 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1141 0.0408 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0831 0.0411 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0206 0.0417 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0088 0.0402 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0249 0.0422 sec/batch
# Nearest to three: two, zero, four, five, six, eight, nine, one,
# Nearest to only: all, telomere, minarets, revolutionizing, completions, tackles, civilisation, meteoroids,
# Nearest to four: two, three, one, five, zero, seven, eight, six,
# Nearest to such: superpowered, zionist, metalworking, nevermind, experimental, extremism, bibliographical, duplication,
# Nearest to about: quotes, resurrection, guesswork, occasion, crisis, hibernate, edu, prevalence,
# Nearest to or: reserved, ultrasonic, anything, attainable, unprotected, centipede, expressions, gallienus,
# Nearest to many: sociopolitical, martial, bitkeeper, weizmann, theropod, stranding, maintaining, ramone,
# Nearest to history: sharif, chronology, goers, amg, lefkow, brief, multivariate, cyclopedia,
# Nearest to troops: amphibious, reprisal, militiamen, infiltrators, shahade, putsch, ecclestone, occupation,
# Nearest to nobel: prize, phys, maslow, goddard, hawley, laureate, thysanoessa, kenny,
# Nearest to notes: saka, era, harp, congruences, masala, chattanooga, expound, flops,
# Nearest to prince: kal, monastic, septimania, brother, etat, sixteenth, airforce, kora,
# Nearest to active: mpr, sanctioning, capablanca, nonsignatory, disingenuous, athos, pentecostals, passive,
# Nearest to mathematics: studied, miletus, urundi, schl, layton, funniest, mit, emendations,
# Nearest to magazine: abingdon, news, columbine, purist, comedies, alphabetically, scuba, koch,
# Nearest to freedom: greetings, exptime, laodicea, escalation, modernisation, generalizations, insurance, mcqueen,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9355 0.0426 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9795 0.0408 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0412 0.0409 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9844 0.0405 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0362 0.0410 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0200 0.0357 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9952 0.0411 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9324 0.0412 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9717 0.0412 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9326 0.0418 sec/batch
# Nearest to three: two, zero, four, five, eight, six, nine, one,
# Nearest to only: all, minarets, revolutionizing, telomere, completions, tackles, civilisation, brightest,
# Nearest to four: two, three, one, five, eight, zero, seven, nine,
# Nearest to such: superpowered, zionist, usage, nevermind, experimental, pluralistic, duplication, hellraiser,
# Nearest to about: quotes, resurrection, occasion, deification, saracens, guesswork, edu, the,
# Nearest to or: reserved, ultrasonic, attainable, unprotected, either, anything, balor, receptive,
# Nearest to many: martial, bitkeeper, sociopolitical, theropod, weizmann, maintaining, stranding, kangol,
# Nearest to history: sharif, goers, chronology, lefkow, brief, cyclopedia, multivariate, myths,
# Nearest to troops: amphibious, reprisal, militiamen, infiltrators, escudo, ecclestone, ritorno, shahade,
# Nearest to nobel: prize, phys, maslow, laureate, goddard, hawley, kenny, thysanoessa,
# Nearest to notes: era, saka, harp, masala, congruences, expound, fifth, flops,
# Nearest to prince: kal, septimania, brother, monastic, kora, sixteenth, etat, airforce,
# Nearest to active: mpr, capablanca, nonsignatory, sanctioning, athos, pentecostals, passive, mixture,
# Nearest to mathematics: studied, miletus, urundi, schl, widely, funniest, layton, mathematical,
# Nearest to magazine: abingdon, news, columbine, purist, archiving, alphabetically, aries, muzzle,
# Nearest to freedom: greetings, laodicea, exptime, generalizations, escalation, mcqueen, modernisation, decrypting,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9484 0.0425 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9133 0.0414 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9651 0.0411 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9739 0.0418 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9917 0.0406 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9466 0.0409 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8724 0.0418 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9167 0.0404 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9123 0.0403 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9243 0.0419 sec/batch
# Nearest to three: two, zero, four, five, six, eight, nine, one,
# Nearest to only: all, minarets, telomere, completions, revolutionizing, tackles, brightest, had,
# Nearest to four: two, three, one, five, zero, seven, eight, six,
# Nearest to such: zionist, experimental, superpowered, usage, metalworking, extremism, duplication, pluralistic,
# Nearest to about: quotes, resurrection, edu, saberhagen, occasion, guesswork, prevalence, saracens,
# Nearest to or: ultrasonic, reserved, unprotected, balor, centipede, either, is, attainable,
# Nearest to many: martial, bitkeeper, sociopolitical, theropod, weizmann, stranding, maintaining, kangol,
# Nearest to history: cyclopedia, sharif, chronology, brief, lefkow, goers, amg, multivariate,
# Nearest to troops: amphibious, reprisal, infiltrators, militiamen, wounded, ritorno, ecclestone, shahade,
# Nearest to nobel: prize, phys, maslow, goddard, laureate, thysanoessa, hawley, kenny,
# Nearest to notes: saka, era, harp, fifth, fingering, masala, flops, expound,
# Nearest to prince: kal, septimania, monastic, kora, donohue, brother, sixteenth, etat,
# Nearest to active: mpr, sanctioning, nonsignatory, capablanca, pentecostals, disingenuous, gulags, oscars,
# Nearest to mathematics: studied, miletus, funniest, widely, schl, layton, mit, mathematical,
# Nearest to magazine: abingdon, news, columbine, purist, archiving, alphabetically, outlook, aries,
# Nearest to freedom: greetings, exptime, generalizations, laodicea, escalation, mcqueen, modernisation, insurance,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9710 0.0419 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9915 0.0415 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9418 0.0419 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0090 0.0410 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9996 0.0401 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9134 0.0410 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9512 0.0405 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9599 0.0406 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9708 0.0410 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9797 0.0423 sec/batch
# Nearest to three: zero, two, four, five, six, one, eight, nine,
# Nearest to only: all, telomere, revolutionizing, minarets, completions, tackles, fj, had,
# Nearest to four: two, one, three, five, seven, zero, eight, nine,
# Nearest to such: usage, experimental, hellraiser, zionist, superpowered, duplication, extremism, subduction,
# Nearest to about: quotes, resurrection, occasion, saberhagen, crisis, edu, prevalence, at,
# Nearest to or: ultrasonic, balor, reserved, attainable, centipede, unprotected, anything, is,
# Nearest to many: bitkeeper, martial, weizmann, sociopolitical, theropod, incorporates, ramone, cards,
# Nearest to history: cyclopedia, sharif, lefkow, goers, brief, cerebus, chronology, external,
# Nearest to troops: amphibious, reprisal, infiltrators, shahade, escudo, militiamen, ritorno, rebels,
# Nearest to nobel: prize, phys, maslow, laureate, goddard, hawley, thysanoessa, kenny,
# Nearest to notes: saka, era, harp, fingering, fifth, congruences, airborne, flops,
# Nearest to prince: kal, brother, septimania, monastic, clan, kora, sixteenth, etat,
# Nearest to active: nonsignatory, mpr, sanctioning, passive, disingenuous, pentecostals, hco, capablanca,
# Nearest to mathematics: studied, miletus, widely, mathematical, funniest, layton, mit, schl,
# Nearest to magazine: abingdon, news, columbine, alphabetically, purist, archiving, aries, scuba,
# Nearest to freedom: greetings, exptime, generalizations, laodicea, escalation, mcqueen, modernisation, insurance,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9727 0.0420 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9653 0.0410 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9438 0.0403 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9667 0.0413 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9946 0.0412 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9816 0.0413 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9447 0.0417 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9310 0.0415 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9458 0.0413 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9660 0.0408 sec/batch
# Nearest to three: two, zero, four, five, six, one, nine, eight,
# Nearest to only: all, telomere, minarets, revolutionizing, completions, the, tackles, had,
# Nearest to four: two, one, three, five, seven, eight, zero, nine,
# Nearest to such: usage, experimental, zionist, superpowered, hellraiser, extremism, refers, originating,
# Nearest to about: quotes, at, number, crisis, resurrection, edu, prevalence, saberhagen,
# Nearest to or: ultrasonic, reserved, is, attainable, either, balor, unprotected, are,
# Nearest to many: bitkeeper, sociopolitical, weizmann, martial, theropod, stranding, incorporates, zygmunt,
# Nearest to history: sharif, cyclopedia, chronology, lefkow, brief, goers, external, myths,
# ...
# Nearest to notes: saka, fingering, era, nzd, airborne, harp, zine, chattanooga,
# Nearest to prince: kal, clan, brother, kora, septimania, sixteenth, librarian, whitechapel,
# Nearest to active: mpr, nonsignatory, capablanca, sanctioning, passive, athos, pentecostals, gulags,
# Nearest to mathematics: studied, miletus, mathematical, widely, bibliotheca, latterly, schl, mit,
# Nearest to magazine: abingdon, columbine, muzzle, news, cyclopaedia, nebula, magazines, alphabetically,
# Nearest to freedom: greetings, exptime, modernisation, escalation, generalizations, laodicea, indiscriminate, hudsucker,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.8878 0.0431 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.8409 0.0408 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.9159 0.0402 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.8109 0.0402 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9304 0.0415 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.9163 0.0421 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.8894 0.0409 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9557 0.0130 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.8565 0.0404 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.8581 0.0408 sec/batch
# Nearest to three: two, zero, five, four, nine, eight, six, one,
# Nearest to only: all, minarets, had, telomere, completions, revolutionizing, the, cleansed,
# Nearest to four: two, one, three, five, eight, seven, zero, nine,
# Nearest to such: usage, superpowered, zionist, experimental, isolating, or, popularising, definiendum,
# Nearest to about: at, saberhagen, quotes, crisis, to, ningbo, imdb, plainfield,
# Nearest to or: are, either, balor, anything, ultrasonic, is, such, may,
# Nearest to many: martial, bitkeeper, weizmann, kangol, sociopolitical, squads, that, propagandistic,
# Nearest to history: cyclopedia, external, sharif, lefkow, watchmaker, chronology, article, terracotta,
# Nearest to troops: amphibious, lagrand, infiltrators, escudo, ecclestone, understandable, cambodians, lighten,
# Nearest to nobel: prize, laureate, phys, maslow, murdered, hawley, thysanoessa, phillip,
# Nearest to notes: saka, fingering, era, nzd, zine, expound, harp, chord,
# Nearest to prince: kal, clan, brother, kora, septimania, sixteenth, librarian, whitechapel,
# Nearest to active: passive, athos, capablanca, mpr, manifest, hco, nonsignatory, pentecostals,
# Nearest to mathematics: studied, mathematical, widely, miletus, latterly, bibliotheca, mit, machine,
# Nearest to magazine: abingdon, muzzle, news, columbine, magazines, cyclopaedia, alphabetically, nebula,
# Nearest to freedom: greetings, generalizations, exptime, escalation, modernisation, laodicea, leads, hudsucker,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8691 0.0427 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.8632 0.0429 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8270 0.0408 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.8654 0.0416 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8099 0.0401 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.8698 0.0406 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.8975 0.0405 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9343 0.0407 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8135 0.0414 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.8398 0.0410 sec/batch
# Nearest to three: two, zero, five, four, six, nine, eight, one,
# Nearest to only: all, had, minarets, completions, telomere, the, revolutionizing, in,
# Nearest to four: two, one, five, three, zero, seven, eight, nine,
# Nearest to such: usage, or, as, superpowered, isolating, hellraiser, popularising, known,
# Nearest to about: crisis, saberhagen, at, ningbo, quotes, to, plainfield, guesswork,
# Nearest to or: are, either, a, balor, such, may, is, an,
# Nearest to many: martial, kangol, bitkeeper, weizmann, squads, sociopolitical, incorporates, extraneous,
# Nearest to history: cyclopedia, external, references, article, sharif, chronology, watchmaker, terracotta,
# Nearest to troops: amphibious, lagrand, cambodians, infiltrators, escudo, ecclestone, leninist, understandable,
# Nearest to nobel: prize, laureate, phys, maslow, hawley, thysanoessa, murdered, unbearable,
# Nearest to notes: saka, fingering, nzd, airborne, era, naw, zine, cont,
# Nearest to prince: kal, kora, clan, brother, septimania, sixteenth, librarian, whitechapel,
# Nearest to active: passive, capablanca, athos, nonsignatory, mpr, gulags, sanctioning, hco,
# Nearest to mathematics: studied, latterly, widely, mathematical, miletus, bibliotheca, machine, mit,
# Nearest to magazine: abingdon, news, alphabetically, magazines, columbine, cyclopaedia, muzzle, weekly,
# Nearest to freedom: greetings, modernisation, escalation, generalizations, laodicea, exptime, mcqueen, indiscriminate,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8481 0.0429 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8086 0.0405 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8565 0.0400 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.8800 0.0399 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8767 0.0413 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.8621 0.0406 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.9139 0.0406 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8673 0.0407 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8404 0.0408 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.8687 0.0399 sec/batch
# Nearest to three: two, zero, four, five, one, six, eight, nine,
# Nearest to only: all, the, completions, had, telomere, minarets, revolutionizing, in,
# Nearest to four: two, one, three, five, seven, zero, eight, nine,
# Nearest to such: or, usage, as, superpowered, hellraiser, metalworking, isolating, popularising,
# Nearest to about: at, saberhagen, crisis, quotes, resurrection, to, plainfield, ningbo,
# Nearest to or: are, either, an, is, such, may, balor, a,
# Nearest to many: bitkeeper, martial, kangol, that, various, large, incorporates, coronets,
# Nearest to history: cyclopedia, external, watchmaker, references, terracotta, sharif, lefkow, article,
# Nearest to troops: amphibious, lagrand, cambodians, infiltrators, escudo, ecclestone, invulnerable, lucio,
# Nearest to nobel: prize, laureate, phys, maslow, hawley, murdered, thysanoessa, branched,
# Nearest to notes: saka, fingering, nzd, era, airborne, fifth, naw, chattanooga,
# Nearest to prince: kal, clan, brother, kora, septimania, sixteenth, librarian, whitechapel,
# Nearest to active: passive, athos, hco, capablanca, gulags, mpr, manifest, orrin,
# Nearest to mathematics: studied, miletus, latterly, widely, machine, bibliotheca, mathematical, schl,
# Nearest to magazine: abingdon, news, weekly, magazines, alphabetically, nebula, cyclopaedia, published,
# Nearest to freedom: greetings, exptime, generalizations, escalation, modernisation, laodicea, mcqueen, indiscriminate,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.8543 0.0426 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9076 0.0410 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.8664 0.0413 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.8927 0.0413 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.8670 0.0418 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.8662 0.0404 sec/batch
# Epoch 7/10 Iteration: 30700 Avg. Training loss: 3.8712 0.0406 sec/batch
# Epoch 7/10 Iteration: 30800 Avg. Training loss: 3.8643 0.0418 sec/batch
# Epoch 7/10 Iteration: 30900 Avg. Training loss: 3.8655 0.0444 sec/batch
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 3.8642 0.0431 sec/batch
# Nearest to three: two, zero, five, four, six, one, nine, eight,
# Nearest to only: all, had, the, minarets, completions, telomere, in, fj,
# Nearest to four: two, one, five, three, seven, eight, zero, nine,
# Nearest to such: usage, or, as, superpowered, refers, metalworking, hellraiser, experimental,
# Nearest to about: at, saberhagen, crisis, to, guesswork, quotes, imdb, plainfield,
# Nearest to or: are, is, a, either, balor, such, of, may,
# Nearest to many: large, bitkeeper, various, kangol, coronets, as, extraneous, martial,
# Nearest to history: cyclopedia, external, article, sharif, watchmaker, references, chronology, lefkow,
# Nearest to troops: amphibious, lagrand, cambodians, escudo, navarre, ecclestone, lucio, visitors,
# Nearest to nobel: prize, laureate, phys, maslow, hawley, murdered, thysanoessa, branched,
# Nearest to notes: fingering, saka, nzd, airborne, chord, reeds, era, fifth,
# Nearest to prince: kal, clan, brother, kora, septimania, sixteenth, soga, librarian,
# Nearest to active: passive, athos, hco, capablanca, gulags, nonsignatory, sanctioning, mpr,
# Nearest to mathematics: studied, miletus, latterly, mathematical, widely, bibliotheca, machine, mit,
# Nearest to magazine: magazines, news, abingdon, alphabetically, cyclopaedia, xe, published, weekly,
# Nearest to freedom: greetings, exptime, escalation, laodicea, generalizations, modernisation, indiscriminate, hudsucker,
# Epoch 7/10 Iteration: 31100 Avg. Training loss: 3.8590 0.0424 sec/batch
# Epoch 7/10 Iteration: 31200 Avg. Training loss: 3.8742 0.0418 sec/batch
# Epoch 7/10 Iteration: 31300 Avg. Training loss: 3.8748 0.0428 sec/batch
# Epoch 7/10 Iteration: 31400 Avg. Training loss: 3.9235 0.0428 sec/batch
# Epoch 7/10 Iteration: 31500 Avg. Training loss: 3.9656 0.0423 sec/batch
# Epoch 7/10 Iteration: 31600 Avg. Training loss: 3.9075 0.0420 sec/batch
# Epoch 7/10 Iteration: 31700 Avg. Training loss: 3.8892 0.0413 sec/batch
# Epoch 7/10 Iteration: 31800 Avg. Training loss: 3.8399 0.0423 sec/batch
# Epoch 7/10 Iteration: 31900 Avg. Training loss: 3.8727 0.0407 sec/batch
# Epoch 7/10 Iteration: 32000 Avg. Training loss: 3.7644 0.0424 sec/batch
# Nearest to three: two, zero, four, five, six, one, eight, nine,
# Nearest to only: all, the, had, minarets, telomere, completions, at, fj,
# Nearest to four: two, one, five, three, zero, seven, nine, eight,
# Nearest to such: usage, or, as, known, definiendum, popularising, isolating, superpowered,
# Nearest to about: at, crisis, saberhagen, plainfield, to, ningbo, quotes, imdb,
# Nearest to or: are, is, an, either, such, a, balor, of,
# Nearest to many: large, bitkeeper, martial, various, kangol, coronets, extraneous, incorporates,
# Nearest to history: cyclopedia, external, article, references, sharif, watchmaker, terracotta, chronology,
# Nearest to troops: lagrand, amphibious, escudo, visitors, cambodians, ecclestone, kosova, infiltrators,
# Nearest to nobel: prize, laureate, phys, maslow, murdered, hawley, awarded, winners,
# Nearest to notes: fingering, saka, nzd, airborne, chord, gaon, fifth, chattanooga,
# Nearest to prince: kal, clan, brother, kora, sixteenth, septimania, etat, soga,
# Nearest to active: passive, athos, capablanca, hco, gulags, orrin, manifest, pentecostals,
# Nearest to mathematics: studied, miletus, mathematical, widely, latterly, bibliotheca, machine, hausdorff,
# Nearest to magazine: abingdon, magazines, news, weekly, cyclopaedia, alphabetically, nebula, muzzle,
# Nearest to freedom: greetings, exptime, escalation, modernisation, laodicea, generalizations, schreiber, indiscriminate,
# Epoch 7/10 Iteration: 32100 Avg. Training loss: 3.8888 0.0439 sec/batch
# Epoch 7/10 Iteration: 32200 Avg. Training loss: 3.8587 0.0419 sec/batch
# Epoch 7/10 Iteration: 32300 Avg. Training loss: 3.8519 0.0415 sec/batch
# Epoch 8/10 Iteration: 32400 Avg. Training loss: 3.9183 0.0019 sec/batch
# Epoch 8/10 Iteration: 32500 Avg. Training loss: 3.8531 0.0419 sec/batch
# Epoch 8/10 Iteration: 32600 Avg. Training loss: 3.8462 0.0413 sec/batch
# Epoch 8/10 Iteration: 32700 Avg. Training loss: 3.8061 0.0419 sec/batch
# Epoch 8/10 Iteration: 32800 Avg. Training loss: 3.8558 0.0420 sec/batch
# Epoch 8/10 Iteration: 32900 Avg. Training loss: 3.8027 0.0423 sec/batch
# Epoch 8/10 Iteration: 33000 Avg. Training loss: 3.8417 0.0429 sec/batch
# Nearest to three: two, zero, four, five, six, one, eight, nine,
# Nearest to only: all, had, the, telomere, minarets, completions, at, revolutionizing,
# Nearest to four: two, one, five, three, eight, seven, zero, nine,
# Nearest to such: usage, or, as, superpowered, definiendum, hellraiser, popularising, refers,
# Nearest to about: at, saberhagen, crisis, to, guesswork, plainfield, the, ningbo,
# Nearest to or: are, an, either, balor, is, a, and, such,
# Nearest to many: large, that, bitkeeper, but, various, as, some, kangol,
# Nearest to history: cyclopedia, external, references, article, watchmaker, sharif, terracotta, entrenchment,
# Nearest to troops: lagrand, amphibious, escudo, cambodians, invulnerable, vicksburg, infiltrators, visitors,
# Nearest to nobel: prize, laureate, phys, maslow, polish, murdered, hawley, phillip,
# Nearest to notes: fingering, saka, nzd, airborne, harp, chord, era, gaon,
# Nearest to prince: kal, brother, clan, kora, sixteenth, septimania, etat, hrh,
# Nearest to active: passive, hco, capablanca, athos, gulags, orrin, nonsignatory, manifest,
# Nearest to mathematics: studied, latterly, widely, miletus, mathematical, machine, bibliotheca, mit,
# Nearest to magazine: magazines, news, abingdon, weekly, xe, cyclopaedia, alphabetically, muzzle,
# Nearest to freedom: greetings, modernisation, laodicea, exptime, escalation, generalizations, schreiber, indiscriminate,
# Epoch 8/10 Iteration: 33100 Avg. Training loss: 3.8026 0.0439 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b1d3869cd0d6> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# C:\Users\allxo_000\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\allxo_000\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# C:\Users\allxo_000\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Users\allxo_000\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# C:\Users\allxo_000\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
